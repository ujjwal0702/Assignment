# %% [markdown]
# # Answer 1. Pearson correlation coefficient is a measure of the linear relationship between two variables. Suppose you have collected data on the amount of time students spend studying for an exam and their final exam scores. Calculate the Pearson correlation coefficient between these two variables and interpret the result.

# %% [markdown]
# To calculate the Pearson correlation coefficient, you need the following information:
#
# 1. The data on the amount of time students spend studying for an exam (let's call this variable X).
# 2. The data on their final exam scores (let's call this variable Y).
#
# ![image.png](attachment:cb9c9ed5-894c-4b79-9815-c9b8a1c8538f.png)
#
# Here's a step-by-step guide on how to calculate the Pearson correlation coefficient:
#
# ![image.png](attachment:3d14db4a-14fb-45a9-a82e-750e6d4c8409.png)
#
# The Pearson correlation coefficient ranges from -1 to 1, where:
#
# ![image.png](attachment:31e0443f-40fa-46a7-804b-f33efc951931.png)

# %% [markdown]
# # Answer 2. Spearman's rank correlation is a measure of the monotonic relationship between two variables. Suppose you have collected data on the amount of sleep individuals get each night and their overall job satisfaction level on a scale of 1 to 10. Calculate the Spearman's rank correlation between these two variables and interpret the result.

# %% [markdown]
# Spearman's rank correlation coefficient is used to assess the strength and direction of the monotonic relationship between two variables. A monotonic relationship is a relationship that either consistently increases or consistently decreases.
#
# To compute Spearman's rank correlation coefficient, follow these steps:
#
# 1. Rank the Data: For each variable, rank the data from lowest to highest. If there are ties, assign each tied observation the average of the ranks they would have received if there were no ties.
#
# 2. Compute the Differences: For each observation, calculate the difference between its ranks in the two variables.
#
# 3. Square the Differences: For each observation, square the difference calculated in step 2.
#
# 4. Calculate ρ: Use the formula for Spearman's rank correlation:
#
# ![image.png](attachment:e0e1b13f-8e35-43ce-9a22-c063117e8563.png)
#
# Now, let's compute the Spearman's rank correlation coefficient for the given data on the amount of sleep and job satisfaction level.
#
# After you've ranked the data and computed the differences, let's say you have n paired observations.
#
# Plug the values into the formula to find ρ.
#
# ![image.png](attachment:dd75579e-a910-48a1-8d54-8532d02939cf.png)

# %% [markdown]
# # Answer 3. Suppose you are conducting a study to examine the relationship between the number of hours of exercise per week and body mass index (BMI) in a sample of adults. You collected data on both variables for 50 participants. Calculate the Pearson correlation coefficient and the Spearman's rank correlation between these two variables and compare the results.

# %% [markdown]
# ![image.png](attachment:e3a43f04-f75f-4b4e-b7a6-ceaf715db1e6.png)
#
# ![image.png](attachment:e1d4d132-1375-4657-a5ad-14fa786c74ae.png)
#
# ![image.png](attachment:4a844604-2482-4ffe-b8f5-5b74ce9d8c12.png)

# %% [markdown]
# # Answer 4. A researcher is interested in examining the relationship between the number of hours individuals spend watching television per day and their level of physical activity. The researcher collected data on both variables from a sample of 50 participants. Calculate the Pearson correlation coefficient between these two variables.

# %% [markdown]
# ![image.png](attachment:de739c49-aae0-44f6-ad6e-3c6d9c306f89.png)
#
# ![image.png](attachment:847af99b-562a-43fc-92bf-bb93bb5cc360.png)
#
# Where:
#
# * r is the Pearson correlation coefficient.
# * The numerator represents the sum of the products of the differences between the variables.
# * The denominator represents the product of the square roots of the sums of the squared differences for each variable.
#
# After performing the calculations, you'll obtain the Pearson correlation coefficient r, which will indicate the strength and direction of the linear relationship between the number of hours individuals spend watching television per day and their level of physical activity.

# %% [markdown]
# # Answer 5. A survey was conducted to examine the relationship between age and preference for a particular brand of soft drink. The survey results are shown below:
#
# |Age(Years) | Soft drink Preference|
#
# |    25     |        Coke          |
#
# |   42      |       Pepsi          |
#
# |    37     |    Mountain dew      |
#
# |     19    |        Coke          |
#
# |     31    |       Pepsi          |
#
# |     28    |        Coke          |

# %% [markdown]
# To analyze the relationship between age and preference for a particular brand of soft drink, we can start by summarizing the data using descriptive statistics. Since age is a continuous variable and soft drink preference is a categorical variable, we can look at measures of central tendency and frequency distributions.
#
# 1. Descriptive Statistics for Age:
#
# * Mean: (25+42+37+19+31+28)/6=32
# * Median (since the data is not ordered): 29.5
# * Mode: There's no single mode because no age value appears more than once.
#
# 2. Frequency Distribution for Soft Drink Preference:
#
# * Coke: 3
# * Pepsi: 2
# * Mountain Dew: 1
#
# 3. Visual Inspection:
#
# * From a quick look, it seems that there isn't a clear pattern or trend between age and soft drink preference. The preferences are scattered across the different age values.
#
# To determine if there's a statistically significant relationship between age and soft drink preference, more rigorous statistical tests would be required, such as a chi-square test for independence (since soft drink preference is categorical) or a correlation test (if considering age as a continuous variable).
#
# However, based on the given data:
#
# * Coke appears to be the most preferred brand among the respondents.
# * There doesn't seem to be a clear trend suggesting that older or younger individuals have a specific preference for a soft drink brand.
# For a more definitive analysis and conclusion, a larger dataset would be beneficial, encompassing a wider age range and possibly other demographic variables.

# %% [markdown]
# # Answer 6. A company is interested in examining the relationship between the number of sales calls made per day and the number of sales made per week. The company collected data on both variables from a sample of 30 sales representatives. Calculate the Pearson correlation coefficient between these two variables.

# %% [markdown]
# ![image.png](attachment:a27374a3-ce04-4eb7-aff4-055154dd5121.png)
#
# ![image.png](attachment:002fa541-3d53-4f7a-9684-4db57285aa78.png)
#
# ![image.png](attachment:3e20f0e3-c5af-4992-94f9-99cb6358e1ac.png)
